# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/Python_-using-_gcolab---essentials-/blob/main/PYTHON_tokens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Language comoments
Identifiers
Literals
Operators
Keywords
Comments
Quotations'''
# Out:
# 'Language comoments\nIdentifiers\nLiterals\nOperators\nKeywords\nComments\nQuotations'

# %%
# Identifiers - Variables / Value Containers
name = "Moni"
age = 26
city = "chennai"

# %%
# Identifiers Types
'''Private Identifiers
Strong private identifiers
magical method identifiers '''
# Out:
# 'Private Identifiers\nStrong private identifiers\nmagical method identifiers '

# %%
_name = 'moni' # Private Identifiers
__name = 'sugan' # Strong private identifiers
a = 20
b = 30
a.__add__(b)
50
a.__add__(b) # magical method identifiers
50
# Out:
# 50

# %%
#Literals - checking the exact datatype of a  value stored in the identifiers
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(city)
# Out:
# str

# %%
type(3.24)
# Out:
# float

# %%
# Operators
'''
Arithmetic operators (+ - * / % //)
Logical operators (and or not)
Relational operator(> >= < <= == !=)
Assignment operator(= += -= *= /= %= //=)
membership operator(in not in)
identity operator (is is not)
'''
# Out:
# '\nArithmetic operators (+ - * / % //)\nLogical operators (and or not)\nRelational operator(> >= < <= == !=)\nAssignment operator(= += -= *= /= %= //=)\nmembership operator(in not in)\nidentity operator (is is not)\n'

# %%
# Arithmetic operators (+ - * / % //)
a + b
# Out:
# 50

# %%
a-b
# Out:
# -10

# %%
a*b
# Out:
# 600

# %%
a/b
# Out:
# 0.6666666666666666

# %%
a%b
# Out:
# 20

# %%
a//b
# Out:
# 0

# %%
a
# Out:
# 20

# %%
b
# Out:
# 30

# %%
divmod(48,5)
# Out:
# (9, 3)

# %%
# logical operators(and or not)
a
# Out:
# 20

# %%
b
# Out:
# 30

# %%
a==b
# Out:
# False

# %%
a == 20
# Out:
# True

# %%
b == 30
# Out:
# True

# %%
a == 20 and b == 30
# Out:
# True

# %%
a == 10  and b == 30
# Out:
# False

# %%
a == 20 or b == 40
# Out:
# True

# %%
a == 2 or b == 4
# Out:
# False

# %%
#Relational operator (> >= < <= == !=)
a = 20

# %%
b = 30

# %%
a > b
# Out:
# False

# %%
a >= b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# Assignment operator(= += -= *= /= %= //=)
a = 20
a += 10 # a = a + 10
a
# Out:
# 30

# %%
a -= 5 # a = a - 5
a
# Out:
# 20

# %%
a *= 2 # a = a * 2
a
# Out:
# 80

# %%
a /= 5 # a = a / 5
a
# Out:
# 3.2

# %%
a %= 3 # a = a %= 3

# %%
a
# Out:
# 0.20000000000000018

# %%
a = 20
a //= 2 # a = a // 2

# %%
a
# Out:
# 10

# %%
a = int(a)

# %%
a
# Out:
# 10

# %%
# Membership operator(in not in)
'o' in 'moni'
# Out:
# True

# %%
'b' in 'moni'
# Out:
# False

# %%
'a' not in 'moni'
# Out:
# True

# %%
'o' not in 'moni'
# Out:
# False

# %%
#identity operator (is is not)
a
# Out:
# 10

# %%
b
# Out:
# 30

# %%
a == 10
# Out:
# True

# %%
a is 10
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_2326/2365217341.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   a is 10
# True

# %%
b is not 3
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_2326/493378019.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   b is not 3
# True

# %%
a is not 1
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_2326/2998851572.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   a is not 1
# True

# %%
b is 30
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_2326/2741612154.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   b is 30
# True

# %%
b is not 30
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_2326/2123373604.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   b is not 30
# False

# %%
a is not 30
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_2326/2232085979.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   a is not 30
# True

# %%
#Identity operators are used in payment gateways / wifi password validation
#Membership operators are used in contact book(search)/ dialpad launcher/ google search/ gmaps search

# %%
#KEYWORDS - reserved word with a specific meaning

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
'''Looping Statements(LPS) ---> for / while
Decision making stmts (DMS) ---> if / else / elif
Flow contral statements (FCS) ---> break / pass / continue
User defined fuctions (UDF) ---> def / return / yield
OOPs ---> class / del
exception handling ---> try / except / finally
Boolean login value ---> true / false
Modules programming ---> import / from / as
logical operaters ---> and / or / not
file handling ---> with '''
# Out:
# 'Looping Statements(LPS) ---> for / while\nDecision making stmts (DMS) ---> if / else / elif\nFlow contral statements (FCS) ---> break / pass / continue\nUser defined fuctions (UDF) ---> def / return / yield \nOOPs ---> class / del\nexception handling ---> try / except / finally\nBoolean login value ---> true / false\nModules programming ---> import / from / as\nlogical operaters ---> and / or / not\nfile handling ---> with '

# %%
# comments and quotations
# single  line  comments

# %%
''' muilts line
comments '''
# Out:
# ' muilts line\ncomments '

# %%
# %run /content/muilt_line_comments.py
# Out:
# padma
# surya
# sanjay
# sara
# abhinav
# aditi

# %%
# !python /content/muilt_line_comments.py
# Out:
# monisha
# sugan
# husband wife
