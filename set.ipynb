# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/Python_-using-_gcolab---essentials-/blob/main/set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python Collections - Non primitive Datatypes
# ------
# List / tuple / set / Dictionary

# %%
# set
# set is enclosed with {} - curly braces
# set is an unordersed collections of dataset
# set values are unindexed
# set never support duplicate values
# set values are popped from beginning to end (FIFO)
# set supports  heterogenous values

# %%
basket = {'apple', 'orange', 'pear', 'banana', 'grapes'}
basket
# Out:
# {'apple', 'banana', 'grapes', 'orange', 'pear'}

# %%
type(basket)
# Out:
# set

# %%
basket.add("watermelon")

# %%
basket
# Out:
# {'apple', 'banana', 'grapes', 'orange', 'pear', 'watermelon'}

# %%
basket.add("apple")

# %%
basket
# Out:
# {'apple', 'banana', 'grapes', 'orange', 'pear', 'watermelon'}

# %%
basket.pop()
# Out:
# 'grapes'

# %%
basket
# Out:
# {'apple', 'banana', 'orange', 'pear', 'watermelon'}

# %%
basket.remove("banana")

# %%
basket
# Out:
# {'apple', 'orange', 'pear', 'watermelon'}

# %%
basket.update(["banana","orange"])

# %%
basket
# Out:
# {'apple', 'banana', 'orange', 'pear', 'watermelon'}

# %%
basket = frozenset(basket) # basket becomes immutable

# %%
basket
# Out:
# frozenset({'apple', 'banana', 'orange', 'pear', 'watermelon'})

# %%
 # set operations

# %%
squares = {1,4,9,16,25,36,49,64,81,100}
cubes = {1,8,27,64,125,216,343,514,749,1000}

# %%
squares
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81, 100}

# %%
cubes
# Out:
# {1, 8, 27, 64, 125, 216, 343, 514, 749, 1000}

# %%
squares.difference(cubes)
# Out:
# {4, 9, 16, 25, 36, 49, 81, 100}

# %%
cubes.difference(squares)
# Out:
# {8, 27, 125, 216, 343, 514, 749, 1000}

# %%
squares.intersection(cubes)
# Out:
# {1, 64}

# %%
cubes.intersection(squares)
# Out:
# {1, 64}

# %%
squares
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81, 100}

# %%
cubes
# Out:
# {1, 8, 27, 64, 125, 216, 343, 514, 749, 1000}

# %%
squares.discard(25)

# %%
squares.discard(45)

# %%
squares
# Out:
# {1, 4, 9, 16, 36, 49, 64, 81, 100}

# %%
set1 = set()

# %%
set1 # creates  an empty set
# Out:
# set()

# %%
type(set1)
# Out:
# set

# %%
set1.add(1)

# %%
set1
# Out:
# {1}

# %%
set1.update([4,45,6,7,8,23])

# %%
set1
# Out:
# {1, 4, 6, 7, 8, 23, 45}

# %%
set1.difference_update(squares)

# %%
set1
# Out:
# {6, 7, 8, 23, 45}

# %%
set1.intersection_update(squares)

# %%
set1
# Out:
# set()

# %%
squares.intersection_update(set1)

# %%
squares
# Out:
# set()

# %%
squares.update([4,9,16,25])

# %%
squares
# Out:
# {4, 9, 16, 25}

# %%
set1.add(45)

# %%
set1
# Out:
# {45}

# %%
squares
# Out:
# {4, 9, 16, 25}

# %%
set1
# Out:
# {45}

# %%
squares.update([1,4,9,16,25,36,49,64,81,100])

# %%
squares
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81, 100}

# %%
set1
# Out:
# {45}

# %%
set1.update([4,9,16,49])

# %%
set1
# Out:
# {4, 9, 16, 45, 49}

# %%
set1.issubset(squares)
# Out:
# False

# %%
set1.intersection_update(squares)

# %%
set1
# Out:
# {4, 9, 16, 49}

# %%
set1.issubset(squares)
# Out:
# True

# %%
squares.issuperset(set1)
# Out:
# True

# %%
set1.isdisjoint(squares)
# Out:
# False

# %%
set1.symmetric_difference(squares)
# Out:
# {1, 25, 36, 64, 81, 100}

# %%
set1.symmetric_difference_update(squares)

# %%
set1
# Out:
# {1, 25, 36, 64, 81, 100}

# %%
set2 = cubes.copy()

# %%
set2
# Out:
# {1, 8, 27, 64, 125, 216, 343, 514, 749, 1000}

# %%
set1.difference(set2)
# Out:
# {25, 36, 81, 100}

# %%
set1.intersection(set2)
# Out:
# {1, 64}

# %%
set1.isdisjoint(set2)
# Out:
# False

# %%
set2.clear()

# %%
set2
# Out:
# set()

# %%
set2.add(33)

# %%
set2
# Out:
# {33}

# %%
set2.add(39)

# %%
set2
# Out:
# {33, 39}

# %%
set2.isdisjoint(set1)
# Out:
# True
