# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/Python_-using-_gcolab---essentials-/blob/main/string_handling_managements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # type "help" "copyright" "credits" or "license" for more information

# %%
#string handling management

# %% [markdown]
# #-----------------------------------------------------

# %%
#String Indexing - way to access individual characters in a string using its index value.
#Index value of a string starts from 0.

# %%
text = "python programming"

# %%
text[0] #Index value of a string starts from 0.
# Out:
# 'p'

# %%
text[1]
# Out:
# 'y'

# %%
text[2]
# Out:
# 't'

# %%
text[3]
# Out:
# 'h'

# %%
text[4]
# Out:
# 'o'

# %%
text[5]
# Out:
# 'n'

# %%
text[6] #Spaces are also characters so it will take an index position.
# Out:
# ' '

# %%
text[7]
# Out:
# 'p'

# %%
text[8]
# Out:
# 'r'

# %%
text[9]
# Out:
# 'o'

# %%
text[10]
# Out:
# 'g'

# %%
text[11]
# Out:
# 'r'

# %%
text[12]
# Out:
# 'a'

# %%
text[13]
# Out:
# 'm'

# %%
text[14]
# Out:
# 'm'

# %%
text[15]
# Out:
# 'i'

# %%
text[16]
# Out:
# 'n'

# %%
text[17]
# Out:
# 'g'

# %%
text[18] #text[18] - IndexError: string index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_594/3752405442.py in <cell line: 0>()
# ----> 1 text[18] #text[18] - IndexError: string index out of range
#
# IndexError: string index out of range

# %%
#Negative Indexing
text[-1] #negative Index value of a string starts from -1.
# Out:
# 'g'

# %%
text[-2]
# Out:
# 'n'

# %%
text[-3]
# Out:
# 'i'

# %%
text[-4]
# Out:
# 'm'

# %%
text[-5]
# Out:
# 'm'

# %%
text[-6]
# Out:
# 'a'

# %%
text[-7]
# Out:
# 'r'

# %%
text[-8]
# Out:
# 'g'

# %%
text[-9]
# Out:
# 'o'

# %%
text[-10]
# Out:
# 'r'

# %%
text[-11]
# Out:
# 'p'

# %%
text[-12]
# Out:
# ' '

# %%
text[-13]
# Out:
# 'n'

# %%
text[-14]
# Out:
# 'o'

# %%
text[-15]
# Out:
# 'h'

# %%
text[-16]
# Out:
# 't'

# %%
text[-17]
# Out:
# 'y'

# %%
text[-18]
# Out:
# 'p'

# %%
# strings slicing - extract a particular portion of a string using (start:stop)
text
# Out:
# 'python programming'

# %%
text[0:6]
# Out:
# 'python'

# %%
text[7:18]
# Out:
# 'programming'

# %%
text[7:19]
# Out:
# 'programming'

# %%
# string ranging - almost similar to slicing but start/ stop is optional here

# %%
text[7:]
# Out:
# 'programming'

# %%
text[5:9]
# Out:
# 'n pr'

# %%
text[0:8]
# Out:
# 'python p'

# %%
text[-1:]
# Out:
# 'g'

# %%
text[-15:]
# Out:
# 'hon programming'

# %%
text[:-15]
# Out:
# 'pyt'

# %%
#string reverse - arrange the given string character in reverse order using (start:stop:step)
text
# Out:
# 'python programming'

# %%
text[::-1]
# Out:
# 'gnimmargorp nohtyp'

# %%
text[::-2]
# Out:
# 'gimropnhy'

# %%
text[::-6]
# Out:
# 'grn'

# %%
text[-1::]
# Out:
# 'g'

# %%
text[-1:-12:-1]
# Out:
# 'gnimmargorp'

# %%
text[-1:-12:-2]
# Out:
# 'gimrop'

# %%
# string concatenation - using '+' operator
text_1 = "python"
text_2 = "programming"
text_1 + text_2
# Out:
# 'pythonprogramming'

# %%
"10" + "10"
# Out:
# '1010'

# %%
'python' + 10 #Type Error: 'python' + 10 (can only conatenate string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_594/148534068.py in <cell line: 0>()
# ----> 1 'python' + 10 #Type Error: 'python' + 10 (can only conatenate string)
#
# TypeError: can only concatenate str (not "int") to str

# %%
'100' + '100'
# Out:
# '100100'

# %%
# string repetition - using "*" operator
text_1
# Out:
# 'python'

# %%
text_1 * 5
# Out:
# 'pythonpythonpythonpythonpython'

# %%
"10" * 5
# Out:
# '1010101010'

# %%
'100' * 3
# Out:
# '100100100'

# %%
"hello world" * 6
# Out:
# 'hello worldhello worldhello worldhello worldhello worldhello world'

# %%
# string formatting
name = 'aditi'
age = 34
#Manual formatting - using str.format() method
print("Hello, {}. you are {} years old".format(name, age))
# Out:
# Hello, aditi. you are 34 years old

# %%
print("Hello, {0}. you are {1} years old".format(name, age))
# Out:
# Hello, aditi. you are 34 years old

# %%
print("Hello, {1}. you are {0} years old".format(name, age))
# Out:
# Hello, 34. you are aditi years old

# %%
#Automatted formatting - using % formatting (%s for strings , %d for integers)
print("hello, %s. you are %d years old" %(name,age))
# Out:
# hello, aditi. you are 34 years old

# %%
# General formatting
print('hello,',name, 'you are ',age,'years old.')
# Out:
# hello, aditi you are  34 years old.

# %%
#Formatted String / f-strings which was introduced in Python 3.6
print(f'hello, {name}. you are {age} years old.')
# Out:
# hello, aditi. you are 34 years old.

# %%
# string supporting functions / dotted functions
name
# Out:
# 'aditi'

# %%
name.capitalize()
# Out:
# 'Aditi'

# %%
name.lower()
# Out:
# 'aditi'

# %%
name.upper()
# Out:
# 'ADITI'

# %%
name.casefold()
# Out:
# 'aditi'

# %%
name.find('d')
# Out:
# 1

# %%
name.index('i') # find the position (index) of a character
# Out:
# 2

# %%
name.find('m') # Used to find the position of a character or substring.
# Out:
# -1

# %%
name.rindex('i')
# Out:
# 4

# %%
name.find('i')
# Out:
# 2

# %%
name.index('s') # Error - substring not found
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_594/1401134858.py in <cell line: 0>()
# ----> 1 name.index('s') # Error - substring not found
#
# ValueError: substring not found

# %% [markdown]
# Method	Not found
# .find()	-1
# .index()	ValueError

# %%
name.center(50)
# Out:
# '                      aditi                       '

# %%
name.ljust(25) # Aligns text to the left and adds spaces/characters on the right.
# Out:
# 'aditi                    '

# %%
name.rjust(50)
# Out:
# '                                             aditi'

# %%
'250'.zfill(10) # Adds zeros at the beginning of a string until it reaches the specified length.
# Out:
# '0000000250'

# %%
'250'.center(10,'*')
# Out:
# '***250****'

# %%
name.ljust(10,'*')
# Out:
# 'aditi*****'

# %%
name.rjust(10,'*')
# Out:
# '*****aditi'

# %%
'250'.ljust(10,'*')
# Out:
# '250*******'

# %%
'250'.rjust(15,"*")
# Out:
# '************250'

# %%
'          python              '.strip()
# Out:
# 'python'

# %%
'          python              '.rstrip()
# Out:
# '          python'

# %%
'          python              '.lstrip()
# Out:
# 'python              '

# %%
'######python'.strip("#")
# Out:
# 'python'

# %%
'www.python.org'.strip('w.org')
# Out:
# 'python'

# %%
name
# Out:
# 'aditi'

# %%
name.count('i')
# Out:
# 2

# %%
name.endswith('k')
# Out:
# False

# %%
name.endswith('i')
# Out:
# True

# %%
name.startswith('a')
# Out:
# True

# %%
name.startswith('j')
# Out:
# False

# %%
'-'.join(["python", "programming", "tutorial"])
# Out:
# 'python-programming-tutorial'

# %%
"/".join(["05","23","2006"])
# Out:
# '05/23/2006'

# %%
'www.python.org'.partition('.') # .partition() is used to split a string into 3 parts based on a specific character or word.
# Out:
# ('www', '.', 'python.org')

# %%
'www.python.org'.rpartition('.')
# Out:
# ('www.python', '.', 'org')

# %%
'pop-poos'.partition('-')
# Out:
# ('pop', '-', 'poos')

# %%
name
# Out:
# 'aditi'

# %%
name.strip('i')
# Out:
# 'adit'

# %%
'malayalaum'.strip('m')
# Out:
# 'alayalau'

# %%
'malayalaum'.removeprefix('m')
# Out:
# 'alayalaum'

# %%
'malayalaum'.removeprefix('mal')
# Out:
# 'ayalaum'

# %%
'malayalaum'.removesuffix('m')
# Out:
# 'malayalau'

# %%
'malayalaum'.removesuffix('mal')
# Out:
# 'malayalaum'

# %%
'malayalaum'.removesuffix('s')
# Out:
# 'malayalaum'

# %%
'python programming'.replace('p', 'P')
# Out:
# 'Python Programming'

# %%
'python programming'.title()
# Out:
# 'Python Programming'

# %%
text
# Out:
# 'python programming'

# %%
text.isalnum() # It checks whether the string contains only letters and/or numbers.
# Out:
# False

# %%
text.isalpha()
# Out:
# False

# %%
text.isascii() # Checks whether all characters are ASCII characters. But some Unicode characters are not ASCII
# Out:
# True

# %%
"123".isascii()
# Out:
# True

# %%
'café'.isascii()
# Out:
# False

# %%
text.isdecimal()
# Out:
# False

# %%
"Python@123".isalnum()
# Out:
# False

# %%
'python123'.isalnum()
# Out:
# True

# %%
'python123'.isalpha()
# Out:
# False

# %%
'python'.isalnum()
# Out:
# True

# %%
'python'.isalpha()
# Out:
# True

# %%
'python123'.isdecimal() # checks whether all characters in the string are decimal digits.
# Out:
# False

# %%
'123'.isdecimal()
# Out:
# True

# %%
'12.4'.isdecimal()
# Out:
# False

# %%
'-12'.isdecimal()
# Out:
# False

# %%
'python_123'.isnumeric()
# Out:
# False

# %%
'VI'.isnumeric()
# Out:
# False

# %%
'123'.isnumeric()
# Out:
# True

# %%
'123'.isprintable() #checks whether all characters in a string are printable.
# Out:
# True

# %%
"prith\nthenty".isprintable() # \n \t is not a printable
# Out:
# False

# %%
'python'.isidentifier()  #Checks whether a string is a valid Python identifier.

# In simple terms, it checks whether something can be used as a variable name.
# Out:
# True

# %%
"123name".isidentifier()
# Out:
# False

# %%
'python123'.isidentifier()
# Out:
# True

# %%
'python'.islower()
# Out:
# True

# %%
'python programming'.isspace()
# Out:
# False

# %%
' '.isspace()
# Out:
# True

# %% [markdown]
# | Method         | `"123"` |   `"²"` |   `"½"` |
# | -------------- | ------: | ------: | ------: |
# | `.isdecimal()` |  ✅ True | ❌ False | ❌ False |
# | `.isdigit()`   |  ✅ True |  ✅ True | ❌ False |
# | `.isnumeric()` |  ✅ True |  ✅ True |  ✅ True |

# %% [markdown]
# | Method           | Meaning                     | Example                 | Result          |
# | ---------------- | --------------------------- | ----------------------- | --------------- |
# | `.partition()`   | Split into 3 parts          | `"a-b".partition("-")`  | `('a','-','b')` |
# | `.isprintable()` | Checks printable characters | `"Hello".isprintable()` | `True`          |
# | `.isdecimal()`   | Checks decimal digits       | `"123".isdecimal()`     | `True`          |
