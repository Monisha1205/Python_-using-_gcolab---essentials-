# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/Python_-using-_gcolab---essentials-/blob/main/tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Non primitive dataset

# %%
# Tuple
# tuple is enclosed with () - paranthesis
# tuple values are ordered collections of data items
# tuple values are indexed
# tuple supports duplicated values
# tuple values are immuteable
# tuple only contains heterogenous values

# %%
t = ("monisha", "sugan", "sharevesh", "mani", "santhi", "sankar", "monisha")

# %%
type(t)
# Out:
# tuple

# %%
t.count("monisha")
# Out:
# 2

# %%
t.index("mani")
# Out:
# 3

# %%
# ways to update values in the tuple

# %%
t = list(t)
t
# Out:
# ['monisha', 'sugan', 'sharevesh', 'mani', 'santhi', 'sankar', 'monisha']

# %%
t.append("123")

# %%
t
# Out:
# ['monisha', 'sugan', 'sharevesh', 'mani', 'santhi', 'sankar', 'monisha', '123']

# %%
type(t)
# Out:
# list

# %%
t = tuple(t) # convert list to tuple

# %%
t
# Out:
# ('monisha', 'sugan', 'sharevesh', 'mani', 'santhi', 'sankar', 'monisha', '123')

# %%
type(t)
# Out:
# tuple

# %%
# tuple concatenation

# %%
t = t + ("12", "34", 45)
t
# Out:
# ('monisha',
#  'sugan',
#  'sharevesh',
#  'mani',
#  'santhi',
#  'sankar',
#  'monisha',
#  '123',
#  '12',
#  '34',
#  45)

# %%
t1 = ("3", '4', "67", "45")
t = t + t1
t
# Out:
# ('monisha',
#  'sugan',
#  'sharevesh',
#  'mani',
#  'santhi',
#  'sankar',
#  'monisha',
#  '123',
#  '12',
#  '34',
#  45,
#  '3',
#  '4',
#  '67',
#  '45',
#  '3',
#  '4',
#  '67',
#  '45')

# %%
t
# Out:
# ('monisha',
#  'sugan',
#  'sharevesh',
#  'mani',
#  'santhi',
#  'sankar',
#  'monisha',
#  '123',
#  '12',
#  '34',
#  45,
#  '3',
#  '4',
#  '67',
#  '45',
#  '3',
#  '4',
#  '67',
#  '45')
