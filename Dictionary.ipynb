# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/Python_-using-_gcolab---essentials-/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python collections - Non primitive datatypes

# %%
# dictionary

# %%
# dictionary is enclosed with {key:values} paired items
# dictionary containes ordered  collections of data  items
# dictionary is not indexed
# dictionary  dont allow  dupilcate values
# dictionary  support heterogenous  data items

# %%
car = {} # create an empty dictionary
type(car)
# Out:
# dict

# %%
car['brand'] = 'vm'
car['model'] = 'polo'
car['price'] = '150000'

# %%
car
# Out:
# {'brand': 'vm', 'model': 'polo', 'price': '150000'}

# %%
car.keys()
# Out:
# dict_keys(['brand', 'model', 'price'])

# %%
car.values()
# Out:
# dict_values(['vm', 'polo', '150000'])

# %%
car.items()
# Out:
# dict_items([('brand', 'vm'), ('model', 'polo'), ('price', '150000')])

# %%
car.get('model')
# Out:
# 'polo'

# %%
car.pop('price')
# Out:
# '150000'

# %%
car
# Out:
# {'brand': 'vm', 'model': 'polo'}

# %%
car.popitem()
# Out:
# ('model', 'polo')

# %%
car
# Out:
# {'brand': 'vm'}

# %%
car.setdefault('model', 'polo')
# Out:
# 'polo'

# %%
car
# Out:
# {'brand': 'vm', 'model': 'polo'}

# %%
value = car.setdefault('model', 'Vento')

# %%
value
# Out:
# 'polo'

# %%
car1 = car.fromkeys(car.keys())

# %%
car1
# Out:
# {'brand': None, 'model': None}

# %%
car
# Out:
# {'brand': 'vm', 'model': 'polo'}
