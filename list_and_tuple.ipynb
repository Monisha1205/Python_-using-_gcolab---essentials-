# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha1205/Python_-using-_gcolab---essentials-/blob/main/list_and_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python Native Datatypes / Python Collections / Python Non-primitive datatypes
#-----------------------------------------------------------------------------
#Primitive Datatypes - store a single value and are completely immutable
# Int - holds positive / negative whole numbers
# Float - represents positive / negative decimal number
# Boolean - evaluates states of logic, exactly True or False
# String - contains sequence of characters enclosed in single/double quotation
# Complex - represent mathematical complex numbers (3 + 4j)

#NON PRIMITIVE DATATYPE - stores multiple values
#----------------------
#List / Tuple / Set / Dictionary
#
#LIST
#----

#enclosed with [] - brackets
#list contains ordered collection of data items
#list values are indexed
#list values are mutable
#list support duplicate values
#list contains heterogenous values

# %%
car = ["creta", "meta", "toyota", "creta", "i20"]

# %%
car
# Out:
# ['creta', 'meta', 'toyota', 'creta', 'i20']

# %%
car[1]
# Out:
# 'meta'

# %%
car[0]
# Out:
# 'creta'

# %%
car[3]
# Out:
# 'creta'

# %%
car[4]
# Out:
# 'i20'

# %%
car[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_607/1172890250.py in <cell line: 0>()
# ----> 1 car[5]
#
# IndexError: list index out of range

# %%
car[0] == car[3]
# Out:
# True

# %%
car
# Out:
# ['creta', 'meta', 'toyota', 'creta', 'i20']

# %%
car[2] = "venue"

# %%
car
# Out:
# ['creta', 'meta', 'venue', 'creta', 'i20']

# %%
car[2:]
# Out:
# ['venue', 'creta', 'i20']

# %%
car[2:4]
# Out:
# ['venue', 'creta']

# %%
car[:2]
# Out:
# ['creta', 'meta']

# %%
# list methods / list operaters / list supporting fucntions

# %%
squares = [1,4,9,25]

# %%
squares
# Out:
# [1, 4, 9, 25]

# %%
squares.append(36)

# %%
squares
# Out:
# [1, 4, 9, 25, 36]

# %%
squares.extend([49,64])

# %%
squares
# Out:
# [1, 4, 9, 25, 36, 49, 64]

# %%
squares.index(9)
# Out:
# 2

# %%
squares.index('9')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_607/4264430515.py in <cell line: 0>()
# ----> 1 squares.index('9')
#
# ValueError: '9' is not in list

# %%
squares.insert(1,"two")

# %%
squares
# Out:
# [1, 'two', 4, 9, 25, 36, 49, 64]

# %%
squares.insert(0,"moni")

# %%
squares
# Out:
# ['moni', 1, 'two', 4, 9, 25, 36, 49, 64]

# %%
squares.insert(9,"four")

# %%
squares
# Out:
# ['moni', 1, 'two', 4, 9, 25, 36, 49, 64, 'four']

# %%
squares[7] = "49"
squares[8] = "64"
squares
# Out:
# ['moni', 1, 'two', 4, 9, 25, 36, '49', '64', 'four']

# %%
squares.pop()
# Out:
# 'four'

# %%
squares
# Out:
# ['moni', 1, 'two', 4, 9, 25, 36, '49', '64']

# %%
squares.pop()
# Out:
# '64'

# %%
squares.remove("two")

# %%
squares
# Out:
# ['moni', 1, 4, 9, 25, 36, '49']

# %%
squares + [49, 64, 81, 100]

# %%
squares + [49, 64, 81, 100]
# Out:
# ['moni', 1, 4, 9, 25, 36, '49', 49, 64, 81, 100]

# %%
squares.append(121)

# %%
squares
# Out:
# ['moni', 1, 4, 9, 25, 36, '49', 121]

# %%
squares.remove("49")

# %%
squares
# Out:
# ['moni', 1, 4, 9, 25, 36, 121]

# %%
squares.pop(0)
# Out:
# 'moni'

# %%
squares.pop()
# Out:
# 121

# %%
squares
# Out:
# [1, 4, 9, 25, 36]

# %%
dup_car = car #shallow copy

# %%
dup_car
# Out:
# ['creta', 'meta', 'venue', 'creta', 'i20']

# %%
car
# Out:
# ['creta', 'meta', 'venue', 'creta', 'i20']

# %%
dup_car[2] = "kushaq"

# %%
dup_car
# Out:
# ['creta', 'meta', 'kushaq', 'creta', 'i20']

# %%
car
# Out:
# ['creta', 'meta', 'kushaq', 'creta', 'i20']

# %%
# the changes in the copied list also changed the original list

# %%
# this concept is called shallow copy

# %%
dup_square = squares.copy() # deep copy

# %%
dup_square
# Out:
# [1, 4, 9, 25, 36]

# %%
dup_square.append("moni")

# %%
dup_square
# Out:
# [1, 4, 9, 25, 36, 'moni']

# %%
squares
# Out:
# [1, 4, 9, 25, 36]

# %%
# the changes in the copied list doesnt affect the originam list

# %%
# this is called deep copy

# %%
car
# Out:
# ['creta', 'meta', 'kushaq', 'creta', 'i20']

# %%
car.count("creta")
# Out:
# 2

# %%
car.reverse()

# %%
car
# Out:
# ['i20', 'creta', 'kushaq', 'meta', 'creta']

# %%
car.sort()

# %%
car
# Out:
# ['creta', 'creta', 'i20', 'kushaq', 'meta']

# %%
car.clear()

# %%
car
# Out:
# []

# %%
dup_car
# Out:
# []

# %%
squares.clear()

# %%
squares
# Out:
# []

# %%
dup_square
# Out:
# [1, 4, 9, 25, 36, 'moni']

# %%
dup_square.reverse()

# %%
dup_square
# Out:
# ['moni', 36, 25, 9, 4, 1]

# %%
dup_square.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_607/1040613778.py in <cell line: 0>()
# ----> 1 dup_square.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'
